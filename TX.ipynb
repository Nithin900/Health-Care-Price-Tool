# %%
pip install dtale
# Out:
# ...
#   Using cached dtale-3.17.0-py2.py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached dash_daq-0.5.0.tar.gz (642 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    ---------------- ----------------------- 6.3/14.9 MB 36.5 MB/s eta 0:00:01
#    ------------------------------------ --- 13.6/14.9 MB 34.6 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 29.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------------- ----- 6.8/7.8 MB 33.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 28.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/65.9 MB ? eta -:--:--
#    ---- ----------------------------------- 7.1/65.9 MB 34.7 MB/s eta 0:00:02
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score
# from xgboost import XGBClassifier
# from imblearn.over_sampling import SMOTE  # Install with: pip install imblearn
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\nithi\Downloads\Benefits-Cleaned\TX.csv")
df.head(4)
# Out:
#   StateCode  IssuerId StandardComponentId             PlanId  \
# 0        TX     12846      12846TX0200005  12846TX0200005-00
# 1        TX     12846      12846TX0200005  12846TX0200005-00
# 2        TX     12846      12846TX0200005  12846TX0200005-00
# 3        TX     12846      12846TX0200005  12846TX0200005-00
#
#                        BenefitName   CopayInnTier1  CopayInnTier1-clean  \
# 0  Routine Dental Services (Adult)             NaN                    0
# 1     Dental Check-Up for Children  Not Applicable                    0
# 2        Basic Dental Care - Child  Not Applicable                    0
# 3              Orthodontia - Child  Not Applicable                    0
#
#   CopayInnTier2-clean   CopayOutofNet  CopayOutofNet-clean  ...  \
# 0                 NaN             NaN                    0  ...
# 1                 NaN  Not Applicable                    0  ...
# 2                 NaN  Not Applicable                    0  ...
# ...

# %%
# prompt: keep only numeric columns

import numpy as np
numeric_df = df.select_dtypes(include=np.number)
numeric_df
# Out:
#         IssuerId  CopayInnTier1-clean  CopayOutofNet-clean  \
# 0          12846                    0                    0
# 1          12846                    0                    0
# 2          12846                    0                    0
# 3          12846                    0                    0
# 4          12846                    0                    0
# ...          ...                  ...                  ...
# 320834     98809                    0                    0
# 320835     98809                    0                    0
# 320836     98809                    0                    0
# 320837     98809                    0                    0
# 320838     98809                    0                    0
#
#         CoinsInnTier1-clean  CoinsOutofNet-clean  IsEHB-clean  \
# 0                       0.0                 0.00            0
# 1                       0.0                 0.00            1
# 2                      20.0                 0.20            1
# ...

# %%
numeric_df.drop(columns=['IsExclFromOonMOOP2'], inplace=True)

# %%
# prompt: using TX dataset and dtale

import dtale
import pandas as pd
import numpy as np

# Assuming you have already loaded your DataFrame 'numeric_df'

# Start dtale analysis
d = dtale.show(numeric_df)

# Display the URL to access the interactive analysis in your browser
d = dtale.show(numeric_df, open_browser=True)
